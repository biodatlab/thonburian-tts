# %% [markdown]
# # Demonstration for Thonburian TTS Inference

# %% [markdown]
# ## Connect to GPU Runtime

# %% [markdown]
# ## Download and Install Required Libraries

# %%
# !git clone https://github.com/biodatlab/thonburian-tts.git --quiet

# %%
# !pip install f5-tts --quiet

# %% [markdown]
# ## Run Gradio App

# %%
# !python /content/thonburian-tts/gradio_app.py
